# %% [markdown]
# # 1.import libraries

# %%
import numpy as np
import pandas as pd
import missingno as mn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. import dataset

# %%
df=pd.read_csv("/content/df.csv")

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 380        389    male   31              Engineer             8.0
# 381        394    male   47           Salesperson             6.5
# 382        396    male   29              Engineer             7.8
# 383        399  Female   58                 Nurse             6.8
# 384        400  Female   32                 Nurse             7.5
#
#      Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 0                 6.0                     42.0           6.0     Overweight
# 1                 6.0                     60.0           8.0         Normal
# 2                 6.0                     60.0           8.0         Normal
# 3                 4.0                     30.0           8.0          Obese
# 4                 4.0                     30.0           8.0          Obese
# ..                ...                      ...           ...            ...
# 380               9.0                     80.0           2.0  Normal Weight
# 381               6.0                     40.0           8.0  Normal Weight
# 382               8.0                     55.0           6.0  Normal Weight
# 383               6.0                     30.0           3.0  Normal Weight
# 384               9.0                     70.0           2.0  Normal Weight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83        77.0         4200           None
# 1           125/80        75.0        10000           None
# 2           125/80        75.0        10000           None
# 3           140/90        85.0         3000    Sleep Apnea
# 4           140/90        85.0         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 380         145/98        76.0         8000    Sleep Apnea
# 381         147/80        76.0         8000    Sleep Apnea
# 382         115/95        76.0         8000    Sleep Apnea
# 383         145/88        76.0         8000    Sleep Apnea
# 384         147/79        76.0         8000    Sleep Apnea
#
# [385 rows x 13 columns]

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0               6.0                     42.0           6.0   Overweight
# 1               6.0                     60.0           8.0       Normal
# 2               6.0                     60.0           8.0       Normal
# 3               4.0                     30.0           8.0        Obese
# 4               4.0                     30.0           8.0        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83        77.0         4200           None
# 1         125/80        75.0        10000           None
# 2         125/80        75.0        10000           None
# 3         140/90        85.0         3000    Sleep Apnea
# 4         140/90        85.0         3000    Sleep Apnea

# %%
df.tail()
# Out:
#      Person ID  Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 380        389    male   31     Engineer             8.0               9.0
# 381        394    male   47  Salesperson             6.5               6.0
# 382        396    male   29     Engineer             7.8               8.0
# 383        399  Female   58        Nurse             6.8               6.0
# 384        400  Female   32        Nurse             7.5               9.0
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# 380                     80.0           2.0  Normal Weight         145/98
# 381                     40.0           8.0  Normal Weight         147/80
# 382                     55.0           6.0  Normal Weight         115/95
# 383                     30.0           3.0  Normal Weight         145/88
# 384                     70.0           2.0  Normal Weight         147/79
#
#      Heart Rate  Daily Steps Sleep Disorder
# 380        76.0         8000    Sleep Apnea
# 381        76.0         8000    Sleep Apnea
# 382        76.0         8000    Sleep Apnea
# 383        76.0         8000    Sleep Apnea
# 384        76.0         8000    Sleep Apnea

# %%
df.shape
# Out:
# (385, 13)

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                385 non-null    int64
#  1   Gender                   385 non-null    object
#  2   Age                      385 non-null    int64
#  3   Occupation               385 non-null    object
#  4   Sleep Duration           385 non-null    float64
#  5   Quality of Sleep         385 non-null    float64
#  6   Physical Activity Level  385 non-null    float64
#  7   Stress Level             385 non-null    float64
#  8   BMI Category             385 non-null    object
#  9   Blood Pressure           385 non-null    object
#  10  Heart Rate               385 non-null    float64
#  11  Daily Steps              385 non-null    int64
#  12  Sleep Disorder           385 non-null    object
# dtypes: float64(5), int64(3), object(5)
# memory usage: 39.2+ KB

# %%
df.shape
# Out:
# (385, 13)

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                385 non-null    int64
#  1   Gender                   385 non-null    object
#  2   Age                      385 non-null    int64
#  3   Occupation               385 non-null    object
#  4   Sleep Duration           385 non-null    float64
#  5   Quality of Sleep         385 non-null    float64
#  6   Physical Activity Level  385 non-null    float64
#  7   Stress Level             385 non-null    float64
#  8   BMI Category             385 non-null    object
#  9   Blood Pressure           385 non-null    object
#  10  Heart Rate               385 non-null    float64
#  11  Daily Steps              385 non-null    int64
#  12  Sleep Disorder           385 non-null    object
# dtypes: float64(5), int64(3), object(5)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  385.000000  385.000000      385.000000        385.000000
# mean   193.181818   42.150649        7.133766          7.311688
# std    111.604950    8.718285        0.791723          1.201775
# min      1.000000   27.000000        5.800000          4.000000
# 25%     97.000000   35.000000        6.400000          6.000000
# 50%    193.000000   43.000000        7.200000          7.000000
# 75%    289.000000   50.000000        7.800000          8.000000
# max    400.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               385.000000    385.000000  385.000000    385.000000
# mean                 58.896104      5.366234   70.285714   6832.987013
# std                  20.823905      1.792171    4.207685   1621.575771
# min                  20.000000      2.000000   63.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
mn.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# # Exploratory data analysis[EDA]

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 380        389    male   31              Engineer             8.0
# 381        394    male   47           Salesperson             6.5
# 382        396    male   29              Engineer             7.8
# 383        399  Female   58                 Nurse             6.8
# 384        400  Female   32                 Nurse             7.5
#
#      Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 0                 6.0                     42.0           6.0     Overweight
# 1                 6.0                     60.0           8.0         Normal
# 2                 6.0                     60.0           8.0         Normal
# 3                 4.0                     30.0           8.0          Obese
# 4                 4.0                     30.0           8.0          Obese
# ..                ...                      ...           ...            ...
# 380               9.0                     80.0           2.0  Normal Weight
# 381               6.0                     40.0           8.0  Normal Weight
# 382               8.0                     55.0           6.0  Normal Weight
# 383               6.0                     30.0           3.0  Normal Weight
# 384               9.0                     70.0           2.0  Normal Weight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83        77.0         4200           None
# 1           125/80        75.0        10000           None
# 2           125/80        75.0        10000           None
# 3           140/90        85.0         3000    Sleep Apnea
# 4           140/90        85.0         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 380         145/98        76.0         8000    Sleep Apnea
# 381         147/80        76.0         8000    Sleep Apnea
# 382         115/95        76.0         8000    Sleep Apnea
# 383         145/88        76.0         8000    Sleep Apnea
# 384         147/79        76.0         8000    Sleep Apnea
#
# [385 rows x 13 columns]

# %%
df['Sleep Duration'].value_counts() \
.head(385) \
.plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Sleep Duration'].value_counts() \
.head(385) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Sleep Duration'].value_counts() \
.head(385) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Quality of Sleep'].value_counts() \
.head(385) \
.plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Quality of Sleep'].value_counts() \
.head(385) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Quality of Sleep'].value_counts() \
.head(385) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Physical Activity Level'].value_counts() \
.head(385) \
.plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Physical Activity Level'].value_counts() \
.head(385) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Physical Activity Level'].value_counts() \
.head(385) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Stress Level'].value_counts() \
.head(385) \
.plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Stress Level'].value_counts() \
.head(385) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Stress Level'].value_counts() \
.head(385) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Heart Rate'].value_counts() \
.head(385) \
.plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Heart Rate'].value_counts() \
.head(385) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Heart Rate'].value_counts() \
.head(385) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Daily Steps'].value_counts() \
.head(385) \
.plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Daily Steps'].value_counts() \
.head(385) \
.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Daily Steps'].value_counts() \
.head(385) \
.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.pairplot(df,vars=['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
       'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
       'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
       'Sleep Disorder'])
plt.show()

# %% [markdown]
# # 2D plot

# %%
df.plot(kind='scatter',x='Sleep Duration',y='Stress Level')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Stress Level'>

# %%
df.plot(kind='scatter',x='Sleep Duration',y='Quality of Sleep')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Quality of Sleep'>

# %%
df.plot(kind='scatter',x='Heart Rate',y='Daily Steps')
# Out:
# <Axes: xlabel='Heart Rate', ylabel='Daily Steps'>

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <ipython-input-42-abe2bcd4fc88>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# <Axes: >
